# %% [markdown]
# # Bivariate Choropleth Maps

# %% [markdown]
# Hi there! in this tutorial, we're going to learn how to create bivariate choropleth maps in Python

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# Okay, let's load the spatial boundaries

# %%
gdf = gpd.read_file("data/dissemination-area-hamilton-2016.geojson")
print(gdf)
# Out:
#            a   t   dw   hh        id   pop  rgid     rpid        ruid  rguid  \
# 0    1.97364  DA  152  151  35250030   402  3525  3525005  5370131.00  35537
# 1    7.76241  DA  165  163  35250031   468  3525  3525005  5370131.00  35537
# 2    1.01409  DA  224  221  35250032   614  3525  3525005  5370131.00  35537
# 3    0.28782  DA  225  221  35250033   627  3525  3525005  5370131.00  35537
# 4    0.68027  DA  277  277  35250034   680  3525  3525005  5370131.00  35537
# ..       ...  ..  ...  ...       ...   ...   ...      ...         ...    ...
# 877   0.1705  DA  284  279  35251035   762  3525  3525005  5370120.04  35537
# 878  0.17956  DA  192  190  35251036   628  3525  3525005  5370120.04  35537
# 879  0.60848  DA  269  267  35251037   716  3525  3525005  5370120.04  35537
# 880  0.76015  DA  565  560  35251038  1976  3525  3525005  5370120.04  35537
# 881   1.4554  DA  474  454  35251039  1617  3525  3525005  5370120.04  35537
#
# ...

# %%
gdf.plot(
    facecolor="none", edgecolor="k", linewidth=0.4
);
